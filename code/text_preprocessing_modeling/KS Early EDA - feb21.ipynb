# %%
import pandas as pd
import numpy as np
import glob, os
import datetime
import json

import pickle

import ks_clean as ks

pd.set_option('display.max_columns', None)  
# pd.set_option('display.max_colwidth', 125)  # or 199

# %%
path_dec2018 =r'/Users/robertpagano/Desktop/Kickstarter Data/Kickstarter_2018-12-13'

# %%
df_dec2018 = ks.clean_final_1(path_dec2018)

# %%
df_dec2018 = ks.clean_final_2(df_dec2018)
df_dec2018.tail(5)
# Out:
#         backers_count                                              blurb  \
# 207222            140  Worrisome Wilf is a little boy with a BIZARRE ...
# 207223              0  With this art project, I'm using my body as th...
# 207224             26  We need your help to build an aquaponics learn...
# 207225             21  Naughty Molly is a children's book inspired by...
# 207226              2  A year series of raw videos capturing the peop...
#
#         converted_pledged_amount country     goal          id  \
# 207222                      8949      GB   5500.0  1000770149
# 207223                         0      US  20000.0   950200819
# 207224                      1190      US  50000.0    81288606
# 207225                      1520      US   1500.0   460259204
# 207226                         6      US  35000.0  1831557730
#
#                                                      name  pledged  \
# 207222                   Worrisome Wilf's Beastly Bedtime   5721.0
# ...

# %%
df_dec2018.describe()
# Out:
#        backers_count  converted_pledged_amount          goal            id  \
# count  207227.000000              2.072270e+05  2.072270e+05  2.072270e+05
# mean      147.107785              1.220195e+04  4.545652e+04  1.074692e+09
# std      1037.500265              9.157183e+04  1.141367e+06  6.190318e+08
# min         0.000000              0.000000e+00  1.000000e-02  1.852000e+04
# 25%         4.000000              1.110000e+02  1.500000e+03  5.376902e+08
# 50%        27.000000              1.575000e+03  5.000000e+03  1.078658e+09
# 75%        86.000000              6.279500e+03  1.300000e+04  1.609181e+09
# max    105857.000000              1.026684e+07  1.000000e+08  2.147476e+09
#
#             pledged  state_changed_at   usd_pledged  time_to_launch  \
# count  2.072270e+05      2.072270e+05  2.072270e+05   207227.000000
# mean   1.395777e+04      1.419359e+09  1.220398e+04       40.719472
# std    1.344853e+05      7.090853e+07  9.158168e+04      109.485708
# ...

# %%
df_dec2018['creator_id'].nunique()

###Creator ID is unique creator. It's slightly smaller than "id" which is project, and profile id which is same as id
# Out:
# 162764

# %%
with open('/Users/robertpagano/metis_data/project_4/interim/jan_2019_cleaned.pickle', 'rb') as f:
    df_jan2019 = pickle.load(f)

# %%
df_jan2019.loc[df_jan2019['state'] == 'successful']
# Out:
#         backers_count                                              blurb  \
# 2                 243  We are a team of restaurant pros looking to fu...
# 3                  27  Loosely-based on a Lakota legend, Grandfather ...
# 7                  89  A young director tries to show a film about a ...
# 9                   8  SA allows the card giver to send a video, audi...
# 10                 27  A 62 page comic following the intertwining liv...
# 11                 74  The world premiere of an endearing play about ...
# 13                 40  Made with recycled and sustainable materials, ...
# 14                 17  I just released my first single, "I'm a Tease"...
# 16                 22  A poetry chapbook set on the public transit of...
# 18                 19  An illustrated book series about a young woman...
# 19                101  A short film about wearing multiple masks and ...
# 20                 32  Al Otro Lado es un cortometraje estudiantil de...
# ...

# %%
df_dec2018.loc[df_dec2018['state'] == 'live']
# Out:
#         backers_count                                              blurb  \
# 6                   3  Put a hydrangea flower on your wrist. \r\n\r\n...
# 39                  2  I wrote a book called "American Dream My Way" ...
# 73                 21  A coming of age short film about a young boy c...
# 112                 1  Hand-crafted products dedicated to transform l...
# 115                 2  We will be starting a homemade craft business ...
# 150                 1  Will make a online photo-book and video websit...
# 209                 4  Custom Graffiti pieces as gifts, and or decora...
# 259                 5  A Sci fi action comic of two assassin sisters ...
# 295              1328  After more than 2 years of intense  R&D we are...
# 325               106  Cool monsters, Artifacts, Side Quests and item...
# 327               259  Compatible With LEGO®| Versatile Magnetic Conn...
# 332                21  Grow and evolve your own creature in this crea...
# ...

# %%
df_jan2019.loc[df_jan2019['id'] == 612945694]
# Out:
#         backers_count           blurb  converted_pledged_amount country  \
# 127017              2  By UsClock.net                         6      US
#
#           goal         id                                               name  \
# 127017  7500.0  612945694  Lighted Clock with Family Photos or a Business...
#
#         pledged                                               slug  \
# 127017      6.0  lighted-clock-with-family-photos-or-a-business...
#
#         staff_pick   state  state_changed_at  usd_pledged        date_created  \
# 127017       False  failed        1546477200          6.0 2018-11-29 17:23:25
#
#              deadline_date       launched_date  date_state_changed  \
# 127017 2019-01-03 01:00:00 2018-11-30 22:58:56 2019-01-03 01:00:00
#
#         time_to_launch  day_limit  category_id   category_name  \
# 127017               1         33           27  Graphic Design
#
#         category_position          category_slug  creator_id  profile_id  \
# ...

# %%
df_dec2018['day_limit'].value_counts()
# Out:
# 30    83022
# 60    14070
# 29    11879
# 45     8269
# 31     6154
# 35     5058
# 40     4846
# 20     4202
# 59     4113
# 21     4023
# 28     3705
# 25     3517
# 32     3466
# 15     2986
# 33     2914
# 14     2759
# 34     2320
# 44     2037
# 27     2034
# 24     1695
# 36     1671
# 22     1533
# 26     1528
# 39     1514
# 23     1419
# 10     1411
# 37     1387
# 50     1339
# 38     1181
# 19     1076
#       ...
# 62      123
# 88      119
# 65      102
# 70      101
# 63       88
# 2        85
# 1        84
# 66       83
# 75       82
# 80       64
# 71       62
# 86       54
# 69       49
# 64       47
# 72       45
# 87       45
# 84       44
# 68       43
# 67       39
# 85       37
# 91       37
# 76       36
# 73       36
# 77       36
# 79       35
# 78       35
# 82       33
# 81       32
# 83       29
# 74       28
# Name: day_limit, Length: 91, dtype: int64
