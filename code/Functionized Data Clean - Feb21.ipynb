# %%
import pandas as pd
import numpy as np
import glob, os
import datetime
import json

import pickle

pd.set_option('display.max_columns', None)  
# pd.set_option('display.max_colwidth', 125)  # or 199

# %%
import ks_clean as ks

# %%
path_jan2019 =r'/Users/robertpagano/Desktop/Kickstarter Data/Kickstarter_2019-01-17'

# %% [markdown]
# Here are the steps to clean the data so far:
#  - import ks_clean (contains all merging, parsing, and cleaning functions
#  - create a variable to the path of my data files. Each data pull contains 50+ csv files. Point to the folder that contains them
#  - run ks.clean_final_1 on the path, and then ks.clean_final_2 on the df
#
# To do:
#  - Clean December2018, and then append future statuses to projects that are currently running during December time frame. This will be my target for prediction
#  - Find the counts by category main or subtype, to see what data I can work with once that's done
#  - If not enough data, will need to add previous months.
#
#  - The final dataframe will just be observations that are currently in the middle of their campaign, that have some kind of status at the end. Will need enough successes, so keep iterating through months to get this

# %%
df_jan2019 = ks.clean_final_1(path_jan2019)
df_jan2019.tail(5)
# Out:
#         index  backers_count  \
# 207843   3822             86
# 207844   3823             20
# 207845   3824             24
# 207846   3825            186
# 207847   3826            803
#
#                                                     blurb  \
# 207843  1000+ pages for $5.00! Two highly acclaimed sp...
# 207844  I would like to purchase photo and video equip...
# 207845  Having a baby or looking for the perfect gift ...
# 207846  A hotel, a traveller, a seemingly endless nigh...
# 207847  Turn-based tactical combat and strategy game s...
#
#                                                  category  \
# 207843  {"id":252,"name":"Graphic Novels","slug":"comi...
# 207844  {"id":15,"name":"Photography","slug":"photogra...
# 207845  {"id":341,"name":"Wearables","slug":"technolog...
# 207846  {"id":35,"name":"Video Games","slug":"games/vi...
# 207847  {"id":35,"name":"Video Games","slug":"games/vi...
#
#         converted_pledged_amount country  created_at  \
# ...

# %%
df_jan2019 = ks.clean_final_2(df_jan2019)
df_jan2019.tail(5)
# Out:
#         backers_count                                              blurb  \
# 207843             86  1000+ pages for $5.00! Two highly acclaimed sp...
# 207844             20  I would like to purchase photo and video equip...
# 207845             24  Having a baby or looking for the perfect gift ...
# 207846            186  A hotel, a traveller, a seemingly endless nigh...
# 207847            803  Turn-based tactical combat and strategy game s...
#
#         converted_pledged_amount country      goal          id  \
# 207843                      2293      AU    1000.0  2075668219
# 207844                       627      US     575.0   458068137
# 207845                      1175      CA  100000.0  1138681061
# 207846                      2158      GB    1500.0  1482644582
# 207847                     75584      US   75000.0  2067309003
#
#                                                      name   pledged  \
# 207843  Bringing The Lesser Evil & Peaceful Tomorrows ...   2902.66
# ...

# %%
with open('/Users/robertpagano/metis_data/project_4/interim/jan_2019_cleaned.pickle', 'wb') as to_write:
    pickle.dump(df_jan2019, to_write)

# %%
df_jan2019['category_main'].nunique()
